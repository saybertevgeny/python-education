# %%
import pandas as pd

# %%
 pwd
# Out:
# 'C:\\Users\\evgeny\\DataSinceCourse'

# %%
pd.read_csv('example.csv',sep=';')
# Out:
#           CONTRACT_NUNBER  IS_FOUND_EXPIRATION_DATE  IS_FOUND_MONTHS  \
# 0     1020200039520000194                         1                0
# 1     1027500662420000110                         1                1
# 2     1027500662420000114                         1                1
# 3     1027900031020000194                         0                0
# 4     1027900031020000238                         1                0
# ...                   ...                       ...              ...
# 3562  3762700392720000280                         0                0
# 3563  3762700392720000310                         0                0
# 3564  3762700392720000310                         1                0
# 3565  3762700392720000350                         1                0
# 3566  3762700392720000350                         0                0
#
#                                         EXPIRATION_DATE  \
# 0                                                   NaN
# ...

# %%
first_ten_rows = pd.read_csv('example.csv',sep=';').head(10) # по умолчанию 5, т.е. если не передать парметр то будет 5

# %%
type(first_ten_rows)
# Out:
# pandas.core.frame.DataFrame

# %%
first_ten_rows.to_csv('my_csv',index=False)

# %%
df = pd.read_excel('время.xlsx') #если не указывать sheetname='Лист1' то возьмет первый

# %%
df
# Out:
#     №                                 Действие             время  \
# 0   1                      Открытие реестра МПГ        18,17 сек
# 1   2              Сброс фильтрации реестра МПГ  1 мин 29,25 сек
# 2   3           Применение быстрых фильтров МПГ           11 сек
# 3   4  Применение фильтрации по 1 номеру заявки           10 сек
# 4   5                       Вход в карточку МПГ        16,37 сек
# 5   6                       Переход в РЗ из МПГ           25 сек
# 6   7                     Сброс фильтрации в РЗ           17 сек
# 7   8    Применение 2 фильтров по столбцам в РЗ           16 сек
# 8   9          Применение быстрого фильтра в РЗ     1 мин 26 сек
# 9  10            Открытие карточки задания в РЗ           25 сек
#
#   необходимо к оптимизации Улучшить время на           Unnamed: 5
# 0                       Да               ДБА      PKG_STG_AREA_PG
# 1                       Да               NaN                  NaN
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.to_excel('myExcel.xlsx', sheet_name='Mysheet') #так же работать можно с json, html И т.д
